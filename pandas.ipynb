# %% [markdown]
# <a href="https://colab.research.google.com/github/AndyJVM/AI2023_AndyVera/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PANDAS HAS TWO DATA STRUCTER
import pandas as pd
tmp=pd.Series(data=(100,200,300,400),index=['carlos','juan','mario','rosita'])

# %%
print(tmp)
# Out:
# carlos    100
# juan      200
# mario     300
# rosita    400
# dtype: int64

# %%
tmp.shape
# Out:
# (4,)

# %%
print(tmp[-2])
# Out:
# 300

# %%
tmp*2
# Out:
# carlos    200
# juan      400
# mario     600
# rosita    800
# dtype: int64

# %%
print(tmp[[1,2,3]])
# Out:
# juan      200
# mario     300
# rosita    400
# dtype: int64

# %%
print(tmp.index)
# Out:
# Index(['carlos', 'juan', 'mario', 'rosita'], dtype='object')

# %%
my_dict  = {'name': 'jhon','age': 25,'city': 'new york'}

# %%
aux={'one':pd.Series((1,2,3),index=['apple','ball','clock']),
      'two': pd.Series((10,20,30),index=['banana','watermelon','pineapple'])   }

# %%
aux
# Out:
# {'one': apple    1
#  ball     2
#  clock    3
#  dtype: int64,
#  'two': banana        10
#  watermelon    20
#  pineapple     30
#  dtype: int64}

# %%
df=pd.DataFrame(aux)

# %%
df.shape
# Out:
# (6, 2)

# %%
df
# Out:
#             one   two
# apple       1.0   NaN
# ball        2.0   NaN
# banana      NaN  10.0
# clock       3.0   NaN
# pineapple   NaN  30.0
# watermelon  NaN  20.0

# %%
df.index
# Out:
# Index(['apple', 'ball', 'banana', 'clock', 'pineapple', 'watermelon'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
df['three']=df['one']*df['two']

# %%
df
# Out:
#             one   two  three
# apple       1.0   NaN    NaN
# ball        2.0   NaN    NaN
# banana      NaN  10.0    NaN
# clock       3.0   NaN    NaN
# pineapple   NaN  30.0    NaN
# watermelon  NaN  20.0    NaN

# %%
df['filtro']=df['one']>2

# %%
df
# Out:
#             one   two  three  filtro
# apple       1.0   NaN    NaN   False
# ball        2.0   NaN    NaN   False
# banana      NaN  10.0    NaN   False
# clock       3.0   NaN    NaN    True
# pineapple   NaN  30.0    NaN   False
# watermelon  NaN  20.0    NaN   False

# %%
#del df['three']

#df2=df.pop('four')

# %%
df
# Out:
#             one   two  filtro
# apple       1.0   NaN   False
# ball        2.0   NaN   False
# banana      NaN  10.0   False
# clock       3.0   NaN    True
# pineapple   NaN  30.0   False
# watermelon  NaN  20.0   False

# %%
tags=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/tags.csv')
ratings=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/ratings01.csv')
pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/movies.csv')
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
tags[:10]
# Out:
#    userId  movieId               tag   timestamp
# 0      18     4141       Mark Waters  1240597180
# 1      65      208         dark hero  1368150078
# 2      65      353         dark hero  1368150079
# 3      65      521     noir thriller  1368149983
# 4      65      592         dark hero  1368150078
# 5      65      668         bollywood  1368149876
# 6      65      898  screwball comedy  1368150160
# 7      65     1248     noir thriller  1368149983
# 8      65     1391              mars  1368150055
# 9      65     1617          neo-noir  1368150217

# %%
print(tags['tag'][:10])
# Out:
# 0         Mark Waters
# 1           dark hero
# 2           dark hero
# 3       noir thriller
# 4           dark hero
# 5           bollywood
# 6    screwball comedy
# 7       noir thriller
# 8                mars
# 9            neo-noir
# Name: tag, dtype: object

# %%
ratings.head(7)
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580
# 5       1      112     3.5  1094785740
# 6       1      151     4.0  1094785734

# %%
ratings.tail(10)
# Out:
#          userId  movieId  rating   timestamp
# 1999990   13567    54004     3.5  1262994633
# 1999991   13567    58154     4.0  1262994642
# 1999992   13567    58559     5.0  1262994213
# 1999993   13567    59333     3.5  1262994526
# 1999994   13567    59369     4.0  1262764264
# 1999995   13567    59725     3.5  1262994714
# 1999996   13567    63062     5.0  1262764337
# 1999997   13567    64957     5.0  1262764172
# 1999998   13567    65216     4.5  1262994367
# 1999999   13567    66203     4.0  1262994418
